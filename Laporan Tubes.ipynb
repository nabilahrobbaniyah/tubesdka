# %% [markdown]
# # Laporan Simulasi Pengelolaan Sampah
#
# ## Dasar Kecerdasan Artifisial
#
# ### Konsep
# - Gerobak mengambil sampah dari rumah ke TPS.
# - Truk mengambil sampah yang telah terkumpul di TPS.
# - Pencarian jarak menggunakan Uniform Cost Search (UCS).
# - Jumlah kendaraan, kapasitas, dan kondisi lingkungan dapat dibuat acak (random).

# %% [markdown]
# ## Tujuan
# Membangun simulasi pengangkutan sampah dengan memanfaatkan representasi graph dan algoritma pencarian UCS.

# %% [markdown]
# ## Kode Program
#  kode Python simulasi yang telah dibuat ke sel kode di bawah ini.

# %%
# Tempel kode simulasi di sini

# %% [markdown]
# ## Hasil Simulasi
# - Jumlah gerobak
# - Jumlah truk
# - Total jarak tempuh
# - Sampah tersisa di rumah
# - Sampah di TPS
# - Jalur kendaraan terpilih

# %% [markdown]
# ## Analisis
# Jelaskan hasil simulasi, efektivitas kendaraan, serta pengaruh randomisasi terhadap hasil.

# %% [markdown]
# ## Kesimpulan
# Tuliskan kesimpulan akhir dari simulasi yang dilakukan.
