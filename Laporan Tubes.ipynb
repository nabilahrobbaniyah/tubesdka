# %% [markdown]
# # Laporan Simulasi Pengelolaan Sampah Desa
#
# Disusun kelompok 9:
#
# Nabilah Robbaniyah
# 1030724000
# Kholifa Ayu Lestari
# 10307200114
# Afiya Nadifa Febianti
# 103072400036
#
# Mata Kuliah: Dasar Kecerdasan Artifisial

# %% [markdown]
# # BAB I PENDAHULUAN

# %% [markdown]
# ## 1.1 Latar Belakang
#
# Tuliskan latar belakang pengelolaan sampah dan penerapan AI pada optimasi rute kendaraan.

# %% [markdown]
# ## 1.2 Rumusan Masalah
#
# 1. ...
# 2. ...
# 3. ...

# %% [markdown]
# ## 1.3 Tujuan
#
# 1. ...
# 2. ...
# 3. ...

# %% [markdown]
# ## 1.4 Manfaat
#
# Tuliskan manfaat penelitian/simulasi.

# %% [markdown]
# # BAB II LANDASAN TEORI

# %% [markdown]
# ## 2.1 Artificial Intelligence (AI)
#
# Penjelasan teori AI.

# %% [markdown]
# ## 2.2 Graph
#
# Penjelasan node, edge, weighted graph.

# %% [markdown]
# ## 2.3 Uniform Cost Search (UCS)
#
# Penjelasan algoritma UCS dan cara kerjanya.

# %% [markdown]
# ## 2.4 Simulasi Pengangkutan Sampah
#
# Penjelasan gerobak, TPS, dan truk.

# %% [markdown]
# # BAB III ANALISIS DAN PERANCANGAN SISTEM

# %% [markdown]
# ## 3.1 Analisis Sistem
#
# Rumah → Gerobak → TPS → Truk

# %% [markdown]
# ## 3.2 Aturan Simulasi
#
# Masukkan parameter simulasi yang digunakan.

# %% [markdown]
# ## 3.3 Struktur Data
#
# Jelaskan House, TPS, Vehicle.

# %% [markdown]
# ## 3.4 Flowchart Sistem
#
# Tempel flowchart di sini.

# %% [markdown]
# # BAB IV IMPLEMENTASI DAN HASIL

# %% [markdown]
# ## 4.1 Implementasi Program

# %%
# Tempel kode simulasi lengkap di sini

# %% [markdown]
# ## 4.2 Hasil Simulasi

# %%
# Tempel output simulasi di sini

# %% [markdown]
# ## 4.3 Visualisasi Graph

# %%
# draw_map()
# draw_map('gerobak_0')
# draw_map('truk_0')

# %% [markdown]
# ## 4.4 Analisis Hasil
#
# Analisis performa gerobak, truk, TPS, dan UCS.

# %% [markdown]
# # BAB V PENUTUP

# %% [markdown]
# ## 5.1 Kesimpulan
#
# Tuliskan kesimpulan.

# %% [markdown]
# ## 5.2 Saran
#
# Tuliskan saran pengembangan sistem.

# %% [markdown]
# # DAFTAR PUSTAKA
#
# 1. Russell & Norvig
# 2. Cormen dkk.
# 3. Referensi lain yang digunakan
